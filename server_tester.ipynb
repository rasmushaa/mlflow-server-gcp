# %%
import os
from datetime import datetime
from dotenv import load_dotenv
import mlflow

# %% [markdown]
# ## Set the remote Tracking URI

# %%
load_dotenv()
mlflow.set_tracking_uri(os.getenv("GCP_MLFLOW_CLOUD_RUN"))

# %% [markdown]
# ## Create a new Experiment to remote

# %%
experiment_name = "Test_Experiment"
if not mlflow.get_experiment_by_name(name=experiment_name):
    mlflow.create_experiment(
        name=experiment_name
    )
experiment = mlflow.get_experiment_by_name(experiment_name)

# %% [markdown]
# ## Define new Run variables

# %%
run_name = datetime.now().strftime("%Y-%m-%d_%H:%M")
tags = {
    "env": "test",
    "data_date": "2023-11-24",
    "model_type": "ElasticNet",
    "experiment_description": "Tutorial MLFlow experiment"
}

# %% [markdown]
# ## Log a new Run to remote

# %%
with mlflow.start_run(
    experiment_id=experiment.experiment_id, 
    run_name=run_name, 
    tags=tags
):
    
    # Log the hyperparameters used in the model
    mlflow.log_param("alpha", 0.1)
    mlflow.log_param("l1_ratio", 0.54)
    mlflow.log_param("random_state", 2)
    mlflow.log_param("max_iter", 42)
    
    # Log the metrics
    mlflow.log_metric("rmse", 2.53456)
    mlflow.log_metric("r2", 5.2341)
    mlflow.log_metric("mae", 3.3431)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 14
#      13 # Log the metrics
# ---> 14 mlflow.log_metric("rmse", 2.53456)
#      15 mlflow.log_metric("r2", 5.2341)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:1009, in log_metric(key, value, step, synchronous, timestamp, run_id, model_id, dataset)
#    1008 for model_id in model_ids:
# -> 1009     return MlflowClient().log_metric(
#    1010         run_id,
#    1011         key,
#    1012         value,
#    1013         timestamp,
#    1014         step,
#    1015         synchronous=synchronous,
#    1016         model_id=model_id,
#    1017         dataset_name=dataset.name if dataset is not None else None,
#    1018         dataset_digest=dataset.digest if dataset is not None else None,
#    1019     )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:2079, in MlflowClient.log_metric(self, run_id, key, value, timestamp, step, synchronous, dataset_name, dataset_digest, model_id)
#    2078 model_id = model_id or get_active_model_id()
# -> 2079 return self._tracking_client.log_metric(
#    2080     run_id,
#    2081     key,
#    2082     value,
#    2083     timestamp,
#    2084     step,
#    2085     synchronous=synchronous,
#    2086     dataset_name=dataset_name,
#    2087     dataset_digest=dataset_digest,
#    2088     model_id=model_id,
#    2089 )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:385, in TrackingServiceClient.log_metric(self, run_id, key, value, timestamp, step, synchronous, dataset_name, dataset_digest, model_id)
#     384 if synchronous:
# --> 385     self.store.log_metric(run_id, metric)
#     386 else:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:739, in RestStore.log_metric(self, run_id, metric)
#     726 req_body = message_to_json(
#     727     LogMetric(
#     728         run_uuid=run_id,
#    (...)    737     )
#     738 )
# --> 739 self._call_endpoint(LogMetric, req_body)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:594, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
# --> 594     response = http_request(**call_kwargs)
#     596 response = verify_rest_response(response, endpoint)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:236, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     235 try:
# --> 236     return _get_http_response_with_retries(
#     237         method,
#     238         url,
#     239         max_retries,
#     240         backoff_factor,
#     241         backoff_jitter,
#     242         retry_codes,
#     243         raise_on_status,
#     244         headers=headers,
#     245         verify=host_creds.verify,
#     246         timeout=timeout,
#     247         respect_retry_after_header=respect_retry_after_header,
#     248         **kwargs,
#     249     )
#     250 except requests.exceptions.Timeout as to:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 with mlflow.start_run(
#       2     experiment_id=experiment.experiment_id,
#       3     run_name=run_name,
#       4     tags=tags
#       5 ):
#       6
#       7     # Log the hyperparameters used in the model
#       8     mlflow.log_param("alpha", 0.1)
#       9     mlflow.log_param("l1_ratio", 0.54)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:260, in ActiveRun.__exit__(self, exc_type, exc_val, exc_tb)
#     258 if any(r.info.run_id == self.info.run_id for r in active_run_stack):
#     259     status = RunStatus.FINISHED if exc_type is None else RunStatus.FAILED
# --> 260     end_run(RunStatus.to_string(status))
#     262 return exc_type is None
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:551, in end_run(status)
#     549 last_active_run_id = run.info.run_id
#     550 _last_active_run_id.set(last_active_run_id)
# --> 551 MlflowClient().set_terminated(last_active_run_id, status)
#     552 if last_active_run_id in run_id_to_system_metrics_monitor:
#     553     system_metrics_monitor = run_id_to_system_metrics_monitor.pop(last_active_run_id)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:3498, in MlflowClient.set_terminated(self, run_id, status, end_time)
#    3453 def set_terminated(
#    3454     self, run_id: str, status: str | None = None, end_time: int | None = None
#    3455 ) -> None:
#    3456     """Set a run's status to terminated.
#    3457
#    3458     Args:
#    (...)   3496
#    3497     """
# -> 3498     self._tracking_client.set_terminated(run_id, status, end_time)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:796, in TrackingServiceClient.set_terminated(self, run_id, status, end_time)
#     792 # Tell the store to stop async logging: stop accepting new data and log already enqueued
#     793 # data in the background. This call is making sure every async logging data has been
#     794 # submitted for logging, but not necessarily finished logging.
#     795 self.store.shut_down_async_logging()
# --> 796 self._log_url(run_id)
#     797 self.store.update_run_info(
#     798     run_id,
#     799     run_status=RunStatus.from_string(status),
#     800     end_time=end_time,
#     801     run_name=None,
#     802 )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:762, in TrackingServiceClient._log_url(self, run_id)
#     760 if host_url is None:
#     761     host_url = self.store.get_host_creds().host.rstrip("/")
# --> 762 run = self.store.get_run(run_id)
#     764 # Check for a special run tag that indicates the run is triggered by evaluation.
#     765 # MLflow already shows a link to evaluation results so no need to print it again.
#     766 if (
#     767     is_eval_tag := run.data.tags.get(MLFLOW_RUN_IS_EVALUATION)
#     768 ) and is_eval_tag.lower() == "true":
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:297, in RestStore.get_run(self, run_id)
#     287 """
#     288 Fetch the run from backend store
#     289
#    (...)    294     A single Run object if it exists, otherwise raises an Exception
#     295 """
#     296 req_body = message_to_json(GetRun(run_uuid=run_id, run_id=run_id))
# --> 297 response_proto = self._call_endpoint(GetRun, req_body)
#     298 return Run.from_proto(response_proto.run)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:591, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     589 if method == "GET":
#     590     call_kwargs["params"] = json_body
# --> 591     response = http_request(**call_kwargs)
#     592 else:
#     593     call_kwargs["json"] = json_body
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:236, in http_request(host_creds, endpoint, method, max_retries, backoff_factor, backoff_jitter, extra_headers, retry_codes, timeout, raise_on_status, respect_retry_after_header, retry_timeout_seconds, **kwargs)
#     233     kwargs["auth"] = fetch_auth(host_creds.auth)
#     235 try:
# --> 236     return _get_http_response_with_retries(
#     237         method,
#     238         url,
#     239         max_retries,
#     240         backoff_factor,
#     241         backoff_jitter,
#     242         retry_codes,
#     243         raise_on_status,
#     244         headers=headers,
#     245         verify=host_creds.verify,
#     246         timeout=timeout,
#     247         respect_retry_after_header=respect_retry_after_header,
#     248         **kwargs,
#     249     )
#     250 except requests.exceptions.Timeout as to:
#     251     raise MlflowException(
#     252         f"API request to {url} failed with timeout exception {to}."
#     253         " To increase the timeout, set the environment variable "
#     254         f"{MLFLOW_HTTP_REQUEST_TIMEOUT!s} to a larger value."
#     255     ) from to
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/request_utils.py:237, in _get_http_response_with_retries(method, url, max_retries, backoff_factor, backoff_jitter, retry_codes, raise_on_status, allow_redirects, respect_retry_after_header, **kwargs)
#     234 env_value = os.getenv("MLFLOW_ALLOW_HTTP_REDIRECTS", "true").lower() in ["true", "1"]
#     235 allow_redirects = env_value if allow_redirects is None else allow_redirects
# --> 237 return session.request(method, url, allow_redirects=allow_redirects, **kwargs)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/requests/adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:942, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     940     retries.sleep(response)
#     941     log.debug("Retry: %s", url)
# --> 942     return self.urlopen(
#     943         method,
#     944         url,
#     945         body,
#     946         headers,
#     947         retries=retries,
#     948         redirect=redirect,
#     949         assert_same_host=assert_same_host,
#     950         timeout=timeout,
#     951         pool_timeout=pool_timeout,
#     952         release_conn=release_conn,
#     953         chunked=chunked,
#     954         body_pos=body_pos,
#     955         preload_content=preload_content,
#     956         decode_content=decode_content,
#     957         **response_kw,
#     958     )
#     960 return response
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/urllib3/connection.py:565, in HTTPConnection.getresponse(self)
#     562 _shutdown = getattr(self.sock, "shutdown", None)
#     564 # Get the response from http.client.HTTPConnection
# --> 565 httplib_response = super().getresponse()
#     567 try:
#     568     assert_header_parsing(httplib_response.msg)
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1428 try:
#    1429     try:
# -> 1430         response.begin()
#    1431     except ConnectionError:
#    1432         self.close()
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/local/Cellar/python@3.13/3.13.9_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
