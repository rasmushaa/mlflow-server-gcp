# %%
import os
import requests
from datetime import datetime
from dotenv import load_dotenv
import mlflow

# %% [markdown]
# ## Set the remote Tracking URI

# %%
load_dotenv()
url = os.getenv("GCP_MLFLOW_CLOUD_RUN") # The cloud run https-path
token = os.popen("gcloud auth print-identity-token").read().strip()

session = requests.Session()
session.headers["Authorization"] = f"Bearer {token}"

mlflow.set_tracking_uri(url)
mlflow.tracking.request_header_provider = lambda: {"Authorization": f"Bearer {token}"}

# %%
load_dotenv()
mlflow.set_tracking_uri(os.getenv("GCP_MLFLOW_CLOUD_RUN")) # The cloud run https-path

# %% [markdown]
# ## Create a new Experiment to remote

# %%
experiment_name = "Test_Experiment"
if not mlflow.get_experiment_by_name(name=experiment_name):
    mlflow.create_experiment(
        name=experiment_name
    )
experiment = mlflow.get_experiment_by_name(experiment_name)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[39], line 2
#       1 experiment_name = "Test_Experiment"
# ----> 2 if not mlflow.get_experiment_by_name(name=experiment_name):
#       3     mlflow.create_experiment(
#       4         name=experiment_name
#       5     )
#       6 experiment = mlflow.get_experiment_by_name(experiment_name)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:1949, in get_experiment_by_name(name)
#    1915 def get_experiment_by_name(name: str) -> Experiment | None:
#    1916     """
#    1917     Retrieve an experiment by experiment name from the backend store
#    1918
#    (...)   1947         Creation timestamp: 1662004217511
#    1948     """
# -> 1949     return MlflowClient().get_experiment_by_name(name)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:1798, in MlflowClient.get_experiment_by_name(self, name)
#    1766 def get_experiment_by_name(self, name: str) -> Experiment | None:
#    1767     """Retrieve an experiment by experiment name from the backend store
#    1768
#    1769     Args:
#    (...)   1796         Lifecycle_stage: active
#    1797     """
# -> 1798     return self._tracking_client.get_experiment_by_name(name)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:280, in TrackingServiceClient.get_experiment_by_name(self, name)
#     272 def get_experiment_by_name(self, name):
#     273     """
#     274     Args:
#     275         name: The experiment name.
#    (...)    278         :py:class:`mlflow.entities.Experiment`
#     279     """
# --> 280     return self.store.get_experiment_by_name(name)
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:865, in RestStore.get_experiment_by_name(self, experiment_name)
#     863 try:
#     864     req_body = message_to_json(GetExperimentByName(experiment_name=experiment_name))
# --> 865     response_proto = self._call_endpoint(GetExperimentByName, req_body)
#     866     return Experiment.from_proto(response_proto.experiment)
#     867 except MlflowException as e:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/Ohjelmointi/vscode/mlflow-server-gcp/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:321, in verify_rest_response(response, endpoint)
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
# --> 321         raise MlflowException(
#     322             f"{base_msg}. Response body: '{response.text}'",
#     323             error_code=get_error_code(response.status_code),
#     324         )
#     326 # Skip validation for endpoints (e.g. DBFS file-download API) which may return a non-JSON
#     327 # response
#     328 if endpoint.startswith(_REST_API_PATH_PREFIX) and not _can_parse_as_json_object(response.text):
#
# MlflowException: API request to endpoint /api/2.0/mlflow/experiments/get-by-name failed with error code 403 != 200. Response body: '
# <html><head>
# <meta http-equiv="content-type" content="text/html;charset=utf-8">
# <title>403 Forbidden</title>
# </head>
# <body text=#000000 bgcolor=#ffffff>
# <h1>Error: Forbidden</h1>
# <h2>Your client does not have permission to get URL <code>/api/2.0/mlflow/experiments/get-by-name?experiment_name=Test_Experiment</code> from this server.</h2>
# <h2></h2>
# </body></html>
# '

# %% [markdown]
# ## Define new Run variables

# %%
run_name = datetime.now().strftime("%Y-%m-%d_%H:%M")
tags = {
    "env": "test",
    "data_date": "2023-11-24",
    "model_type": "ElasticNet",
    "experiment_description": "Tutorial MLFlow experiment"
}

# %% [markdown]
# ## Log a new Run to remote

# %%
with mlflow.start_run(
    experiment_id=experiment.experiment_id, 
    run_name=run_name, 
    tags=tags
):
    
    # Log the hyperparameters used in the model
    mlflow.log_param("alpha", 0.1)
    mlflow.log_param("l1_ratio", 0.54)
    mlflow.log_param("random_state", 2)
    mlflow.log_param("max_iter", 42)
    
    # Log the metrics
    mlflow.log_metric("rmse", 2.53456)
    mlflow.log_metric("r2", 5.2341)
    mlflow.log_metric("mae", 3.3431)
# Out:
# 🏃 View run 2025-11-08_18:26 at: https://mlflow-server-109245832287.europe-north1.run.app/#/experiments/1/runs/4c3e7b9444bc4cdba693719d009488af
# 🧪 View experiment at: https://mlflow-server-109245832287.europe-north1.run.app/#/experiments/1
